# %%
import pandas as pd
import sqlite3
import seaborn as sns
from nltk import sent_tokenize
# from pysummarization.nlpbase.auto_abstractor import AutoAbstractor
# from pysummarization.tokenizabledoc.simple_tokenizer import SimpleTokenizer
# from pysummarization.abstractabledoc.top_n_rank_abstractor import TopNRankAbstractor

# %%
import nltk
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %% [markdown]
# <h3>Load in database

# %%
db = 'all-the-news.db'

# %%
cnx = sqlite3.connect(db)

# %%
df = pd.read_sql_query("SELECT * FROM longform", cnx)

# %% [markdown]
# <h3>Preview of DF

# %%
df.head()
# Out:
#    id                                              title               author  \
# 0   1  Agent Cooper in Twin Peaks is the audience: on...   \nTasha Robinson\n
# 1   2                                  AI, the humanity!       \nSam Byford\n
# 2   3                                  The Viral Machine  \nKaitlyn Tiffany\n
# 3   4  How Anker is beating Apple and Samsung at thei...       \nNick Statt\n
# 4   5  Tour Black Panther’s reimagined homeland with ...       \nKwame Opam\n
#
#          date                                            content  year month  \
# 0  2017-05-31        And never more so than in Showtime’s new...  2017     5
# 1  2017-05-30        AlphaGo’s victory isn’t a defeat for hum...  2017     5
# 2  2017-05-25        Super Deluxe built a weird internet empi...  2017     5
# 3  2017-05-22        Steven Yang quit his job at Google in th...  2017     5
# 4  2017-05-15        Ahead of Black Panther’s 2018 theatrical...  2017     5
#
#   publication  category  digital section   url
# 0       Verge  Longform      1.0    None  None
# 1       Verge  Longform      1.0    None  None
# 2       Verge  Longform      1.0    None  None
# 3       Verge  Longform      1.0    None  None
# 4       Verge  Longform      1.0    None  None

# %%
df.shape
# Out:
# (204135, 12)

# %%
#clean up authors names
df.author = df.author.str.strip('\n')

# %%
#check that it worked
df.head()
# Out:
#    id                                              title           author  \
# 0   1  Agent Cooper in Twin Peaks is the audience: on...   Tasha Robinson
# 1   2                                  AI, the humanity!       Sam Byford
# 2   3                                  The Viral Machine  Kaitlyn Tiffany
# 3   4  How Anker is beating Apple and Samsung at thei...       Nick Statt
# 4   5  Tour Black Panther’s reimagined homeland with ...       Kwame Opam
#
#          date                                            content  year month  \
# 0  2017-05-31        And never more so than in Showtime’s new...  2017     5
# 1  2017-05-30        AlphaGo’s victory isn’t a defeat for hum...  2017     5
# 2  2017-05-25        Super Deluxe built a weird internet empi...  2017     5
# 3  2017-05-22        Steven Yang quit his job at Google in th...  2017     5
# 4  2017-05-15        Ahead of Black Panther’s 2018 theatrical...  2017     5
#
#   publication  category  digital section   url
# 0       Verge  Longform      1.0    None  None
# 1       Verge  Longform      1.0    None  None
# 2       Verge  Longform      1.0    None  None
# 3       Verge  Longform      1.0    None  None
# 4       Verge  Longform      1.0    None  None

# %%
#cut down columns
df = df[['title', 'author', 'content', 'year', 'month', 'category']]

# %%
#check for null values
df.isnull().sum()
# Out:
# title           0
# author      32135
# content     12954
# year        12603
# month       12603
# category    35422
# dtype: int64

# %%
#drop all rows where there is no article text
df.dropna(subset=['content'], inplace = True)

# %%
#check new shape of df
df.shape
# Out:
# (191181, 6)

# %%
#verify no null values in content column
df.isnull().sum()
# Out:
# title           0
# author      20502
# content         0
# year         5518
# month        5518
# category    27703
# dtype: int64

# %%
#view counts of article categories
df.groupby('category').title.count()
# Out:
# category
# Book Reviews       20
# Exclusive         214
# Longform          137
# Reports           854
# broadcast       18672
# business         8344
# general         52152
# newspaper       60365
# radio           12001
# wire            10719
# Name: title, dtype: int64

# %%
#create new column for the character length of each article
df['len_article'] = df.content.str.len()

# %%
#drop rows where article is <2,500 or >15,000 characters
df = df[(df.len_article >= 2500) & (df.len_article <= 15000)]

# %%
df.head()
# Out:
#                                                 title          author  \
# 0   Agent Cooper in Twin Peaks is the audience: on...  Tasha Robinson
# 1                                   AI, the humanity!      Sam Byford
# 6                                      Massive attack    Colin Lecher
# 9                                         Brain drain    Casey Newton
# 32                              Facebook takes flight    Casey Newton
#
#                                               content  year month  category  \
# 0         And never more so than in Showtime’s new...  2017     5  Longform
# 1         AlphaGo’s victory isn’t a defeat for hum...  2017     5  Longform
# 6         How a weapon against war became a weapon...  2017     4  Longform
# 9         Genius quietly laid off a bunch of its e...  2017     3  Longform
# 32        Inside the test flight of Facebook’s fir...  2016     7  Longform
#
#     len_article
# 0         12219
# 1         11068
# 6         14088
# 9         12170
# 32        11967

# %%
#check new shape after dropping additional rows
df.shape
# Out:
# (128946, 7)

# %%
#preview df
#df.head()
# Out:
#                                                 title          author  \
# 0   Agent Cooper in Twin Peaks is the audience: on...  Tasha Robinson
# 1                                   AI, the humanity!      Sam Byford
# 6                                      Massive attack    Colin Lecher
# 9                                         Brain drain    Casey Newton
# 32                              Facebook takes flight    Casey Newton
#
#                                               content  year month  category  \
# 0         And never more so than in Showtime’s new...  2017     5  Longform
# 1         AlphaGo’s victory isn’t a defeat for hum...  2017     5  Longform
# 6         How a weapon against war became a weapon...  2017     4  Longform
# 9         Genius quietly laid off a bunch of its e...  2017     3  Longform
# 32        Inside the test flight of Facebook’s fir...  2016     7  Longform
#
#     len_article
# 0         12219
# 1         11068
# 6         14088
# 9         12170
# 32        11967

# %%
from gensim.summarization.summarizer import summarize

# %%
#create try/accept function to take care of edge case articles
#use gensim summarizer for baseline summary model
def gensim_summarizer(x, ratio_):
    try:
        return summarize(x, ratio = ratio_)
    except:
        return ''

# %%
#test the gensim_summarizer on subset of data
#test_df = df.iloc[:10]
#test_df['gensim_summary'] = test_df.content.apply(lambda x : gensim_summarizer(x, ratio_ = .05))

# %%
#verify that it worked
#test_df

# %%
#apply gensim_summarizer function to each row of full dataframe
df['gensim_summary'] = df.content.apply(lambda x : gensim_summarizer(x, ratio_ = .05))

# %%
#check that it worked
#df.head(100)

# %%
#CHECKPOINT --- save to csv --- NOT NECESSARY IF YOU ARE RUNNING THE WHOLE NOTEBOOK AT ONCE
#df.to_csv('full_df_with_gensim_summaries.csv')

# %%
#CHECKPOINT --- reload in csv if using the checkpoint
df = pd.read_csv('../Data/full_df_with_gensim_summaries.csv')

# %%
df.shape
# Out:
# (97064, 12)

# %%
df = df[df.gensim_summary.str.len() >= 1]

# %%
df.shape
# Out:
# (97064, 11)

# %%
#save to csv
df.to_csv('full_df_with_gensim_summaries.csv')

# %%
#drop unnecessary columns when loading in csv
df.drop(['Unnamed: 0', 'Unnamed: 0.1', 'Unnamed: 0.1.1'], axis = 1, inplace = True)

# %%
#preview
#df.head()
# Out:
#                                                title          author  \
# 0  Agent Cooper in Twin Peaks is the audience: on...  Tasha Robinson
# 1                                  AI, the humanity!      Sam Byford
# 2                                     Massive attack    Colin Lecher
# 3                                        Brain drain    Casey Newton
# 4                              Facebook takes flight    Casey Newton
#
#                                              content    year  month  category  \
# 0        And never more so than in Showtime’s new...  2017.0    5.0  Longform
# 1        AlphaGo’s victory isn’t a defeat for hum...  2017.0    5.0  Longform
# 2        How a weapon against war became a weapon...  2017.0    4.0  Longform
# 3        Genius quietly laid off a bunch of its e...  2017.0    3.0  Longform
# 4        Inside the test flight of Facebook’s fir...  2016.0    7.0  Longform
#
#    len_article                                     gensim_summary
# 0        12219  In the second season finale, back in 1991, the...
# 1        11068  When speaking to DeepMind and Google developer...
# 2        14088  International visitors for the event are commo...
# 3        12170  In a post on the Genius blog at the time, co-f...
# 4        11967  But if your goal is to stay in the air for a l...

# %% [markdown]
# <h3>EDA on full dataframe

# %%
df.author.value_counts().describe()
# Out:
# count    17848.000000
# mean         5.200134
# std         15.872180
# min          1.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max        647.000000
# Name: author, dtype: float64

# %% [markdown]
# There are 17,848 unique authors in the dataframe which is quite diverse. The average author has contributed about 5 articles to the dataframe. The top author (Associated Press) has contributed 647 articles which is to be expected since it's a combination of many writers. This is also the case for a number of the other top contributing authors.

# %%
sns.distplot(df.len_article)

# %%
print('mean:', df.len_article.mean())
print('std:', df.len_article.std())
print('max:', df.len_article.max())
print('min:', df.len_article.min())
# Out:
# mean: 6335.110957718619
# std: 2518.2000609532097
# max: 14999
# min: 2500

# %%
df.shape
# Out:
# (97064, 8)

# %% [markdown]
# The average article in the dataframe is roughly 6,335 characters in length. Taking a generous assumption that the average word is 10 characters in length (this can help account for spaces and punctuation), the average article is roughly 633 words long.

# %% [markdown]
# After cutting out articles with greater than 15k words and less than 2.5k words, we are left with a dataframe composed of just over 97k articles.

# %%
df.month.value_counts()
# Out:
# 3.0     11277
# 1.0     10482
# 2.0     10351
# 4.0      9803
# 10.0     9158
# 6.0      8463
# 5.0      8343
# 12.0     6500
# 11.0     6437
# 9.0      5445
# 8.0      5381
# 7.0      5063
# Name: month, dtype: int64

# %%
#create new df to preserve original data 
shortened_df = pd.read_csv('../Data/df_with_gensim_summaries.csv')

# %%
#drop columns
shortened_df = shortened_df.drop(['Unnamed: 0', 'Unnamed: 0.1', 'author', 
                                  'year', 'month', 'len_article'], axis = 1)

# %%
#create column for first 100 words
shortened_df['split_words'] = shortened_df['content'].str.split()
shortened_df['first_100_words'] = shortened_df['split_words'].apply(lambda x: x[:100])

# %%
#rejoin the words in first 100
shortened_df['first_100'] = shortened_df['first_100_words'].apply(lambda x: ' '.join(x))

# %%
#drop unnecessary columns
#shortened_df = shortened_df.drop(['split_words', 'first_100_words'], axis = 1)

# %%
#tokenize each sentence in the content column
shortened_df['sent_tokenized'] = shortened_df.content.apply(lambda x: sent_tokenize(x, language = 'en'))

# %%
#check that it worked
#shortened_df.sent_tokenized[0]

# %%
#update saved csv
shortened_df.to_csv('../Data/full_df_with_gensim_summaries.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-6ac2bde66733> in <module>
#       1 #update saved csv
# ----> 2 shortened_df.to_csv('full_df_with_gensim_summaries.csv')
#
# NameError: name 'shortened_df' is not defined

# %%
shortened_df.drop(['Unnamed: 0', 'Unnamed: 0.1.1'], axis = 1, inplace = True)

# %%
#preview
shortened_df.head()
# Out:
#                                                title  \
# 0  Agent Cooper in Twin Peaks is the audience: on...
# 1                                  AI, the humanity!
# 2                                     Massive attack
# 3                                        Brain drain
# 4                              Facebook takes flight
#
#                                              content  category  \
# 0        And never more so than in Showtime’s new...  Longform
# 1        AlphaGo’s victory isn’t a defeat for hum...  Longform
# 2        How a weapon against war became a weapon...  Longform
# 3        Genius quietly laid off a bunch of its e...  Longform
# 4        Inside the test flight of Facebook’s fir...  Longform
#
#                                       gensim_summary  \
# 0  In the second season finale, back in 1991, the...
# 1  When speaking to DeepMind and Google developer...
# 2  International visitors for the event are commo...
# 3  In a post on the Genius blog at the time, co-f...
# 4  But if your goal is to stay in the air for a l...
#
#                                            first_100  \
# 0  And never more so than in Showtime’s new serie...
# 1  AlphaGo’s victory isn’t a defeat for humans — ...
# 2  How a weapon against war became a weapon again...
# 3  Genius quietly laid off a bunch of its enginee...
# 4  Inside the test flight of Facebook’s first int...
#
#                                       sent_tokenized
# 0  ['      And never more so than in Showtime’s n...
# 1  ['      AlphaGo’s victory isn’t a defeat for h...
# 2  ['      How a weapon against war became a weap...
# 3  ['      Genius quietly laid off a bunch of its...
# 4  ['      Inside the test flight of Facebook’s f...

# %% [markdown]
# <h3>EDA CONTINUED ON SHORTENED DF

# %%
#shortened_df = pd.read_csv('../Data/full_df_with_gensim_summaries.csv')

# %%
sns.countplot(y="author", hue="class", data=df, palette="Greens_d",
              order=df.author.value_counts().iloc[:10].index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-aefcd25d1b5a> in <module>
#       1 sns.countplot(y="author", hue="class", data=df, palette="Greens_d",
# ----> 2               order=df.author.value_counts().iloc[:10].index)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3551                           estimator, ci, n_boot, units,
#    3552                           orient, color, palette, saturation,
# -> 3553                           errcolor, errwidth, capsize, dodge)
#    3554
#    3555     plotter.value_label = "count"
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'class'

# %%
df.loc[df['category'] == 'radio']
# Out:
#        Unnamed: 0  Unnamed: 0.1  Unnamed: 0.1.1  Unnamed: 0.1.1.1  \
# 47572       47572         47572           72393            126586
# 47573       47573         47573           72397            126590
# 47574       47574         47574           72398            126591
# 47575       47575         47575           72399            126592
# 47576       47576         47576           72400            126593
# 47577       47577         47577           72402            126595
# 47578       47578         47578           72403            126596
# 47579       47579         47579           72404            126597
# 47580       47580         47580           72405            126598
# 47581       47581         47581           72406            126600
# 47582       47582         47582           72407            126601
# 47583       47583         47583           72408            126602
# 47584       47584         47584           72409            126603
# 47585       47585         47585           72410            126604
# 47586       47586         47586           72412            126607
# 47587       47587         47587           72414            126611
# 47588       47588         47588           72416            126614
# 47589       47589         47589           72417            126616
# 47590       47590         47590           72418            126619
# 47591       47591         47591           72419            126621
# 47592       47592         47592           72421            126625
# 47593       47593         47593           72422            126626
# 47594       47594         47594           72423            126627
# 47595       47595         47595           72424            126628
# 47596       47596         47596           72425            126629
# 47597       47597         47597           72430            126634
# 47598       47598         47598           72432            126637
# 47599       47599         47599           72433            126638
# 47600       47600         47600           72434            126639
# 47601       47601         47601           72439            126645
# ...           ...           ...             ...               ...
# 52867       52867         52867           82065            138526
# 52868       52868         52868           82066            138528
# 52869       52869         52869           82067            138529
# 52870       52870         52870           82068            138530
# 52871       52871         52871           82069            138533
# 52872       52872         52872           82071            138535
# 52873       52873         52873           82073            138537
# 52890  [When a political scandal explodes in France, ...  2016.0   12.0
# 52891  [Before the virus overwhelmed Puerto Rico, Zik...  2016.0   12.0
# 52892  [It seems everything today has a flavor wheel,...  2016.0   12.0
# 52893  [President-elect Trump is busy these days with...  2016.0   12.0
# 52894  [It's always interesting for the Goats and Sod...  2016.0   12.0
# 52895  [The election of Donald Trump was a surprise t...  2016.0   11.0
# 52896  [Voters in the English city of Sunderland did ...  2016.0   12.0
#
#       category  len_article                                     gensim_summary
# 47572    radio         7759  And in that sense, this year shows little sign...
# 47573    radio        10722  NPR scoured this document to create an overvie...
# 47574    radio         5241  We end in sukhasana with our hands in prayer a...
# 47575    radio         7070  He also says the findings could help improve o...
# 47576    radio         4876  She often accompanies new arrivals to the groc...
# 47577    radio         8050  He could see horses tilling the land – no trac...
# 47578    radio         5820  yet), I drew my guns and slaughtered my way to...
# 47579    radio         5151  When I moved, I heard nothing but the crunch o...
# 47580    radio         5245  "We feel we have some room to grow, but we und...
# 47581    radio         5514  It could be bad for your brain, too., A diet h...
# 47582    radio         4310  [Who's the YouTube star of 2016?, Adele singin...
# 47583    radio         3346  Hulseman invented the red Solo cup and as Morn...
# 47584    radio         3802  "I played by ear and I invented my own chords,...
# 47585    radio         6764  He was part of a wave of artists who were inte...
# 47586    radio        10162  With the year coming to an end, we thought it ...
# 47587    radio         3989  U.S. coal production in 2016 is projected to b...
# 47588    radio        13149  [In September, reproductive endocrinologist Jo...
# 47589    radio         4788  Shrapnel lodged into his neck and back., It wo...
# 47590    radio         3735  The hot noodles cook the eggs, which set with ...
# 47591    radio         4692  Narrative has a role to play as well, especial...
# 47592    radio         4634  You really love the National Park Service for ...
# 47593    radio         7017  Indeed, many of the year's biggest stories on ...
# 47594    radio         4261  In ways big and small, these women have moved ...
# 47595    radio         5569  In the House, Republicans lost six seats, givi...
# 47596    radio         7056  [Democrats may have lost the House and the Sen...
# 47597    radio         6378  He calls the three-year job "colossal.", Ringe...
# 47598    radio         2934  "But John's lyrics — they're so true they migh...
# 47599    radio         4810  In announcing the speech, Obama said he's just...
# 47600    radio         4570  As the quesadillas turn golden, with the chees...
# 47601    radio         8942  In fact, only 3 percent to 18 percent of sexua...
# ...        ...          ...                                                ...
# 52867    radio         7952  "Its rigid, complex rules designed to protect ...
# 52868    radio         3451  Making Paterson the cool white guy at a black ...
# 52869    radio         7804  [One of the most controversial questions in ed...
# 52870    radio         9581  UK stars similarly positions Ridgeley as a new...
# 52871    radio         6742  The choice, McConnell said, should be made by ...
# 52872    radio         3663  This is where the characters in his 1926 novel...
# 52873    radio         6713  And it surely can't be the worst year of all t...
# 52874    radio         6912  New York joined the growing number of states t...
# 52875    radio         5155  It was his introduction to a nonprofit based i...
# 52876    radio         7178  Margo Wootan of the Center for Science in the ...
# 52877    radio         8137  And it's not just because so-called "fake news...
# 52878    radio         3185  And he's - what kind of dog is he?, FISHER: He...
# 52879    radio         8318  (It's not the only legendary video to include ...
# 52880    radio         7968  Worries about the future of Obamacare may be s...
# 52881    radio         5227  In recent years, challenges to this bureaucrac...
# 52882    radio         5678  Two studies published earlier this month estim...
# 52883    radio         6023  I see them struggling for years and years with...
# 52884    radio         4582  Instead, they're performed in a genizaro commu...
# 52885    radio         5750  Director Raoul Peck mixes archival footage of ...
# 52886    radio         4903  (Virginia peanuts were brought over from Boliv...
# 52887    radio         5740  At the Clinical Trials on Alzheimer's Disease ...
# 52888    radio         6685  The whole sketch was making fun of Drake's und...
# 52889    radio         6007  The researchers also found that compared to mo...
# 52890    radio         6716  At that time, Le Canard Enchainé was censored ...
# 52891    radio         8068  "And he has absolute control to take it or giv...
# 52892    radio         6351  What Chambers has in mind is a flavor tree., "...
# 52893    radio         8213  "He doesn't want people standing out in the co...
# 52894    radio         4424  The piece that took the No. 1 spot, with more ...
# 52895    radio         4107  With Republicans in power in the White House, ...
# 52896    radio         6755  They voted by 61.3 percent to leave the Europe...
#
# [5325 rows x 12 columns]

# %%
newspaper = df.loc[df['category'] == 'newspaper']

# %%
newspaper.shape
# Out:
# (45089, 8)

# %%
ax2= sns.countplot(x= 'author', data=shortened_df)
ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-ae6e288b7acd> in <module>
#       1
# ----> 2 ax2= sns.countplot(x= 'author', data=shortened_df)
#       3 ax2.set_xticklabels(ax2.get_xticklabels(), rotation=45)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in countplot(x, y, hue, data, order, hue_order, orient, color, palette, saturation, dodge, ax, **kwargs)
#    3551                           estimator, ci, n_boot, units,
#    3552                           orient, color, palette, saturation,
# -> 3553                           errcolor, errwidth, capsize, dodge)
#    3554
#    3555     plotter.value_label = "count"
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1605         """Initialize the plotter."""
#    1606         self.establish_variables(x, y, hue, data, orient,
# -> 1607                                  order, hue_order, units)
#    1608         self.establish_colors(color, palette, saturation)
#    1609         self.estimate_statistic(estimator, ci, n_boot)
#
# ~/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     153                 if isinstance(input, string_types):
#     154                     err = "Could not interpret input '{}'".format(input)
# --> 155                     raise ValueError(err)
#     156
#     157             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'author'

# %%
general = df.loc[df['category'] == 'general']

# %%
general.shape
# Out:
# (18738, 8)

# %%
general.author.value_counts()
# Out:
# John Hayward                                          451
# Matthew Yglesias                                      260
# David A. Graham                                       256
# Joel B. Pollak                                        246
# German Lopez                                          233
# Bob Price                                             227
# Aaron Klein                                           224
# Frances Martel                                        219
# Breitbart News                                        211
# Dara Lind                                             187
# Brad Plumer                                           179
# Julia Belluz                                          174
# Todd VanDerWerff                                      173
# Rosa Inocencio Smith                                  172
# Jeff Stein                                            168
# Zack Beauchamp                                        162
# Matthew Boyle                                         160
# Andrew Prokop                                         158
# David Sims                                            153
# Dr. Susan Berry                                       151
# Borzou Daragahi                                       146
# Mike Giglio                                           137
# Julia Hahn                                            136
# Warner Todd Huston                                    135
# Brian Resnick                                         135
# Daniel Nussbaum                                       130
# Dylan Matthews                                        129
# Elaine Godfrey                                        128
# Jerome Hudson                                         128
# Neil Munro                                            123
#                                                      ...
# Arielle Bernstein                                       1
# Alice Ollstein, Tierney Sneed                           1
# Krystie Lee Yandoli                                     1
# Filipe Campante and David Yanagizawa-Drott              1
# David Miller                                            1
# Philip Ball                                             1
# Samantha Montano                                        1
# Jason Greenblatt                                        1
# Siraj Datoo                                             1
# Alexander Hertel-Fernandez and Theda Skocpol            1
# Steve Ronnebeck                                         1
# Rossalyn Warren                                         1
# Zuzana Boehmová                                         1
# Mark Peffley, Marc L. Hutchison, and Michal Shamir      1
# David Randall                                           1
# Kristin Goss                                            1
# Tim Newcomb                                             1
# Janelle Harris                                          1
# Marcus J. Moore                                         1
# Mokhtar Awad                                            1
# Ed Kressy                                               1
# Jon Christian                                           1
# David R. Wheeler                                        1
# Ned Resnikoff                                           1
# Melissa Hanham                                          1
# Will Di Novi                                            1
# Xavier Harding                                          1
# Jon Stanley                                             1
# Melissa Nightingale                                     1
# JILL COLVIN                                             1
# Name: author, Length: 1459, dtype: int64
